# %%
import numpy as np
import pandas as pd
stores = pd.read_csv('stores.csv')

# %%
stores.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
stores.describe()
# Out:
#            Store           Size
# count  45.000000      45.000000
# mean   23.000000  130287.600000
# std    13.133926   63825.271991
# min     1.000000   34875.000000
# 25%    12.000000   70713.000000
# 50%    23.000000  126512.000000
# 75%    34.000000  202307.000000
# max    45.000000  219622.000000

# %%
stores
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# ...

# %%
import matplotlib.pyplot as plt

# %%
stores_group = stores.groupby('Type')

# %%
stores_group.get_group('A').count()

#We can see that type A has max number of stores
# Out:
# Store    22
# Type     22
# Size     22
# dtype: int64

# %%
stores_group.get_group('B').count()

#We can see that type B has 17 stores
# Out:
# Store    17
# Type     17
# Size     17
# dtype: int64

# %%
stores_group.get_group('C').count()

#We can see that type C has only 6 stores
# Out:
# Store    6
# Type     6
# Size     6
# dtype: int64

# %%
stores_group.get_group('A')['Size'].max()
#Type A has max 219622
# Out:
# 219622

# %%
stores_group.get_group('B')['Size'].max()
# Out:
# 140167

# %%
stores_group.get_group('C')['Size'].max()
# Out:
# 42988

# %%
stores_group.get_group('A').sort_values('Size')

#We can see that store 13 of Type A has Max size
# Out:
#     Store Type    Size
# 32     33    A   39690
# 35     36    A   39910
# 0       1    A  151315
# 25     26    A  152513
# 7       8    A  155078
# 39     40    A  155083
# 33     34    A  158114
# 38     39    A  184109
# 40     41    A  196321
# 13     14    A  200898
# 1       2    A  202307
# 5       6    A  202505
# 31     32    A  203007
# 19     20    A  203742
# 30     31    A  203750
# 18     19    A  203819
# 23     24    A  203819
# 26     27    A  204184
# 3       4    A  205863
# 27     28    A  206302
# 10     11    A  207499
# 12     13    A  219622

# %%
stores_group.get_group('B').sort_values('Size')

#We can see that store 21 of Type B has Max size
# Out:
#     Store Type    Size
# 4       5    B   34875
# 2       3    B   37392
# 15     16    B   57197
# 6       7    B   70713
# 16     17    B   93188
# 28     29    B   93638
# 34     35    B  103681
# 11     12    B  112238
# 22     23    B  114533
# 44     45    B  118221
# 21     22    B  119557
# 17     18    B  120653
# 14     15    B  123737
# 8       9    B  125833
# 9      10    B  126512
# 24     25    B  128107
# 20     21    B  140167

# %%
stores_group.get_group('C').sort_values('Size')

#We can see that store 30 of Type A has Max size
# Out:
#     Store Type   Size
# 37     38    C  39690
# 41     42    C  39690
# 36     37    C  39910
# 43     44    C  39910
# 42     43    C  41062
# 29     30    C  42988

# %%
stores_group.get_group('C').describe()
# Out:
#            Store          Size
# count   6.000000      6.000000
# mean   39.000000  40541.666667
# std     5.215362   1304.145033
# min    30.000000  39690.000000
# 25%    37.250000  39745.000000
# 50%    40.000000  39910.000000
# 75%    42.750000  40774.000000
# max    44.000000  42988.000000

# %%
stores_group.get_group('B').describe()
# Out:
#            Store           Size
# count  17.000000      17.000000
# mean   18.352941  101190.705882
# std    11.028039   32371.137916
# min     3.000000   34875.000000
# 25%    10.000000   93188.000000
# 50%    17.000000  114533.000000
# 75%    23.000000  123737.000000
# max    45.000000  140167.000000

# %%
stores_group.get_group('A').describe()
# Out:
#            Store           Size
# count  22.000000      22.000000
# mean   22.227273  177247.727273
# std    13.078269   49392.621098
# min     1.000000   39690.000000
# 25%    11.500000  155840.750000
# 50%    25.000000  202406.000000
# 75%    32.750000  203819.000000
# max    41.000000  219622.000000

# %%
import seaborn as sns

# %%
sns.catplot(x='Type',y='Size',kind='box',data=stores,)
